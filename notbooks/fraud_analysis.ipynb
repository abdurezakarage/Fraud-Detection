# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os
# Add the project root directory to Python path
import sys
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))

# %%
from src.eda_analysis import EDAAnalyzer

# %%
analyzer = EDAAnalyzer()

# %%
import pandas as pd

fraud_df = pd.read_csv("../data/processed/fraud_processed.csv")
credit_df = pd.read_csv("../data/processed/credit_processed.csv")

# %%
fraud_df.columns
# Out:
# Index(['user_id', 'signup_time', 'purchase_time', 'purchase_value',
#        'device_id', 'source', 'browser', 'sex', 'age', 'ip_address', 'class',
#        'ip_integer', 'country'],
#       dtype='object')

# %%
credit_df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
analyzer.analyze_class_distribution(fraud_df)
analyzer.plot_class_distribution(credit_df)
# Out:
# INFO:src.eda_analysis:Analyzing class distribution...
# INFO:src.eda_analysis:Class distribution analysis completed
# INFO:src.eda_analysis:Fraud percentage: 9.36%
# INFO:src.eda_analysis:Imbalance ratio: 0.1033
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
analyzer.plot_class_distribution(fraud_df)
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
analyzer.analyze_fraud_rate_by_hour(fraud_df)
# Out:
# INFO:src.eda_analysis:Analyzing fraud rate by hour...
# INFO:src.eda_analysis:Created time features from column: purchase_time
# INFO:src.eda_analysis:Fraud rate by hour analysis completed
# INFO:src.eda_analysis:Peak fraud hours: [{'hour_of_day': 17, 'fraud_rate': 10.748530776368698}, {'hour_of_day': 9, 'fraud_rate': 10.579619819258337}, {'hour_of_day': 8, 'fraud_rate': 10.145608266791921}]
#     hour_of_day  total_transactions  fraud_count  fraud_rate
# 0             0                6186          553    8.939541
# 1             1                6228          560    8.991651
# 2             2                6338          583    9.198485
# 3             3                6458          614    9.507587
# 4             4                6050          502    8.297521
# 5             5                6189          556    8.983681
# 6             6                6380          594    9.310345
# 7             7                6181          545    8.817343
# ...

# %%
analyzer.plot_fraud_rate_by_hour(fraud_df)
# Out:
# INFO:src.eda_analysis:Analyzing fraud rate by hour...
# INFO:src.eda_analysis:Created time features from column: purchase_time
# INFO:src.eda_analysis:Fraud rate by hour analysis completed
# INFO:src.eda_analysis:Peak fraud hours: [{'hour_of_day': 17, 'fraud_rate': 10.748530776368698}, {'hour_of_day': 9, 'fraud_rate': 10.579619819258337}, {'hour_of_day': 8, 'fraud_rate': 10.145608266791921}]

# %%
analyzer.analyze_fraud_rate_by_day(fraud_df)
# Out:
# INFO:src.eda_analysis:Analyzing fraud rate by day of week...
# INFO:src.eda_analysis:Created time features from column: purchase_time
# INFO:src.eda_analysis:Fraud rate by day analysis completed
#   day_of_week  total_transactions  fraud_count  fraud_rate  day_order
# 1      Monday               21711         2089    9.621851          0
# 5     Tuesday               21314         1669    7.830534          1
# 6   Wednesday               21316         1711    8.026834          2
# 4    Thursday               21586         2119    9.816548          3
# 0      Friday               21522         2192   10.184927          4
# 2    Saturday               21648         2149    9.927014          5
# 3      Sunday               22015         2222   10.093118          6

# %%
analyzer.plot_fraud_rate_by_day(fraud_df)
# Out:
# INFO:src.eda_analysis:Analyzing fraud rate by day of week...
# INFO:src.eda_analysis:Created time features from column: purchase_time
# INFO:src.eda_analysis:Fraud rate by day analysis completed
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...

# %%
analyzer.analyze_amount_distribution(fraud_df)
# Out:
# INFO:src.eda_analysis:Analyzing amount distribution...
# INFO:src.eda_analysis:Amount distribution analysis completed
# INFO:src.eda_analysis:Fraud mean amount: $36.99
# INFO:src.eda_analysis:Legitimate mean amount: $36.93
# {'fraud_amount_stats': {'mean': np.float64(36.993004027983886),
#   'median': np.float64(35.0),
#   'std': np.float64(18.397653690084137),
#   'min': np.int64(9),
#   'max': np.int64(111),
#   'q25': np.float64(22.0),
#   'q75': np.float64(49.0)},
#  'legitimate_amount_stats': {'mean': np.float64(36.92941786347939),
#   'median': np.float64(35.0),
#   'std': np.float64(18.31506387001),
#   'min': np.int64(9),
#   'max': np.int64(154),
#   'q25': np.float64(22.0),
#   'q75': np.float64(49.0)},
#  'amount_difference': {'mean_diff': np.float64(0.06358616450449972),
#   'median_diff': np.float64(0.0)}}

# %%
analyzer.plot_amount_distribution(fraud_df)
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
analyzer.analyze_geographic_patterns(fraud_df)
# Out:
# INFO:src.eda_analysis:Analyzing geographic fraud patterns...
# INFO:src.eda_analysis:Geographic analysis completed
# INFO:src.eda_analysis:Top fraud country: Australia (9.36% fraud rate)
# {'geo_analysis':      country  total_transactions  fraud_count  fraud_rate
#  0  Australia              151112        14151    9.364577,
#  'top_fraud_countries':      country  total_transactions  fraud_count  fraud_rate
#  0  Australia              151112        14151    9.364577,
#  'total_countries': 1,
#  'high_risk_countries': 0}

# %%
analyzer.plot_geographic_patterns(fraud_df)
# Out:
# INFO:src.eda_analysis:Analyzing geographic fraud patterns...
# INFO:src.eda_analysis:Geographic analysis completed
# INFO:src.eda_analysis:Top fraud country: Australia (9.36% fraud rate)

# %%
analyzer.plot_correlation_heatmap(fraud_df)

# %%
results = analyzer.comprehensive_analysis(fraud_df)

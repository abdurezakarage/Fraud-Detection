# %%
import pandas as pd
import numpy as np
from datetime import datetime
import shap
import os
# Add the project root directory to Python path
import sys
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))

# %%
from src.ModelExplainability import ModelExplainability

# %%
explainer = ModelExplainability(
    model_path='../models/best_model.joblib',
    feature_names_path='../models/model_features.joblib',
    data_path='../data/processed/fraud_features_engineered.csv'
)

# %%
explainer.load_model_and_data(sample_size=500)  # Optional: sample to speed up SHAP
# Out:
# ✓ Model loaded successfully from ../models/best_model.joblib
# ✓ Feature names loaded successfully from ../models/model_features.joblib
# ✓ Data loaded successfully from ../data/processed/fraud_features_engineered.csv
#   - Dataset shape: (151112, 74)
# ⚠ Target column 'is_fraud' not found, using all data for SHAP analysis
# ✓ Sampled 500 instances for SHAP analysis
# ✓ Final feature matrix shape: (500, 50)

# %%
explainer.compute_shap_values()
# Out:
# ✓ Computing SHAP values for RandomForestClassifier model...
# ✓ Using TreeExplainer
# ✓ SHAP values computed successfully

# %%
explainer.get_correct_shap_values()
# Out:
# array([[[ 0.01822789, -0.01822789],
#         [ 0.00742011, -0.00742011],
#         [ 0.01144383, -0.01144383],
#         ...,
#         [ 0.01370992, -0.01370992],
#         [ 0.00975706, -0.00975706],
#         [ 0.01683925, -0.01683925]],
#
#        [[ 0.01689695, -0.01689695],
#         [ 0.01056685, -0.01056685],
#         [ 0.01320615, -0.01320615],
#         ...,
#         [ 0.00985592, -0.00985592],
#         [ 0.00728168, -0.00728168],
#         [ 0.01399564, -0.01399564]],
#
#        [[ 0.02407427, -0.02407427],
#         [ 0.00951173, -0.00951173],
#         [ 0.01033274, -0.01033274],
#         ...,
#         [ 0.00600832, -0.00600832],
#         [ 0.01168341, -0.01168341],
#         [ 0.01441963, -0.01441963]],
#
#        ...,
#
#        [[ 0.0161115 , -0.0161115 ],
#         [ 0.00837696, -0.00837696],
#         [ 0.02354454, -0.02354454],
#         ...,
#         [ 0.01128536, -0.01128536],
#         [ 0.00458473, -0.00458473],
#         [ 0.01455734, -0.01455734]],
#
# ...

# %%
explainer.plot_summary()

# %%
explainer._create_custom_summary_plot(getshap_values, max_display)

# %%
explainer.plot_force(index=0)

# %% [markdown]
# explainer.plot_waterfall(index=0)

# %%
explainer.plot_dependence(feature_name='amount', interaction_index='is_fraud', save_path='../plots/shap_dependence_plot.png')

# %%
explainer.plot_beeswarm()

# %%
explainer.get_feature_importance_ranking()

# %%
explainer.analyze_fraud_instances()
